# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd

# %%
urls = ['http://download.post.gov.tw/post/download/County_h_10706.xml'.format(str(i)) for i in range(1,7001)]
urls = urls[::-1] #這樣每天會有最新的
url_list = urls[3:4] # <-- Change the range to assign the pages to crawl

start = time.time()

# %%
ptt = pd.read_json("/Users/derek/Desktop/小鎮村/3750_3850_content_AC.json")
ptt
# Out:
#       Area              City  \
# 0        1            Taipei
# 1        1            Taipei
# 2        3       Tainan City
# 3        1            Taipei
# 4        1           Hsinchu
# 5        1            Taipei
# 6        1            Taipei
# 7        1            Taipei
# 8        3       Tainan City
# 9        1            Taipei
# 10       1            Taipei
# 11       1            Taipei
# 12       1           Hsinchu
# 13       1            Taipei
# 14       1            Taipei
# 15       3    Kaohsiung City
# 16       1            Taipei
# 17       1            Taipei
# 18       3     Pingtung City
# 19       1            Taipei
# 20       4      Hualien City
# 21       1            Taipei
# 22       1            Taipei
# 23       3    Kaohsiung City
# 24       3       Chiayi City
# 25       1            Taipei
# 26       1            Taipei
# 27       1            Taipei
# 28       1            Taipei
# 29       2          Taichung
# ...    ...               ...
# ...

# %%
set(ptt["City"])
# Out:
# {'Adan',
#  'Ann Arbor',
#  'Aobadai',
#  'Bade District',
#  'Bangkok',
#  'Beihe',
#  'Beimiao',
#  'Beixing',
#  'Chang-hua',
#  'Chiayi City',
#  'Columbus',
#  'Dalin',
#  'Dapi',
#  'Douliu',
#  'Dresden',
#  'Eugene',
#  'Fremont',
#  'Fukuoka',
#  'Guishan',
#  'Hampstead',
#  'Hangzhou',
#  'Higashinakano',
#  'Ho Chi Minh City',
#  'Hsinchu',
#  'Hualien City',
#  'Huwei',
#  'Invercargill',
#  'Jiale',
#  'Jungnang-gu',
#  'Kamagaya',
#  'Kaohsiung City',
#  'Kawasaki',
#  'Keelung',
#  'La Jolla',
#  'Magong',
#  'Malacca',
#  'Miaoli',
#  'Motegi',
#  'Nagaoka',
#  'Nagoya',
#  'Nantou City',
#  'Nanzih District',
#  'Ningbo',
#  'Nishitokyo',
#  'Osaka',
#  'Paris',
#  'Phnom Penh',
#  'Pingtung City',
#  'Sakurakabu',
#  'Sanmu',
#  'Sanyi',
#  'Seoul',
#  'Setagaya-ku',
#  'Shimada',
#  'Sugar Land',
#  'Suzhou',
#  'Taichung',
#  'Tainan City',
#  'Taipei',
#  'Taitung City',
#  'Taoyuan District',
#  'The Hague',
#  'Tokyo',
#  'Toufen Township',
#  'Toulouse',
# ...
